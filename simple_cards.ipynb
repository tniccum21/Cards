# %% [markdown]
# <a href="https://colab.research.google.com/github/tniccum21/Cards/blob/master/simple_cards.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Simple cards - a platform for NN learning to play simple trick-based card games

Current status - platform for dealing hands and playing semi-random game built
To do:  build NN to learn/play

"""


import numpy as np
import random
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input, Dense 
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
import time 

CARD_PLAYED = 20
DECK_SIZE = 20


"""
NN stuff
"""

#########################################################################
##  CLASS State
##    contains the complete state of the game as seen by one player
##    high-level:
##      records:
##        the trump suit
##        players current hand
##        recording of each previous round of play in the game, and the order played
##
##    initial constructor initializes the game state to zeros
##    print - prints a nice copy of the situation
##
##
class State:
    # State structure - applies to one game
    # [0]     - trump for current game
    # [1:5]   - cards in player's hand, 0 padded to right
    # [6:25]   - cards played [5 rounds, 4 cards per round]
    # [26:45]    - order played [5 rounds, 4 cards per round]

    def __init__(self):
        self.trump      = 0
        self.mycards    = np.zeros(5)
        self.played     = np.zeros((5, 4))
        self.play_order = np.zeros((5, 4))
    
    def print(self, labels=False):
        pretty_cards = []
        for i in range(5):
#            if self.mycards[i] != 0:
              f = face(self.mycards[i])
              pretty_cards.append(f)
        print("CURRENT SITUATION:")
        print("  Trump:   ", self.trump)  
        print("  My Hand: ", pretty_cards)
        print("  Played:  ")
        print("  Order:   ")

# updates the state with a play
# inputs:
#     round:  the round number of the current game
#     play:   the play number of the current game (0 = leadout)
#     player: the player playing this card
#     card:   the card being played
#     round*5 +1 gets to the head of the array for recording each round and stores the card played
#     round*5 +20 gets to the head of the array for recording the order of play within the round, and stores the player number
    def update(round, play, player, card):
        self.played[round, play] = card 
        self.play_order[round, play] = player
        return None

################################################################################
# CLASS Agent:
#    
#  quick and dirty "strategy" for robotic player imporovement...
#    simply checks to see if:
#       A.  If we can win by moving to a square
#       B.  If we can't win do we need to block the other guy...
#       returns a list of suggested moves

############## NN Model Class ######################
class Agent():
    def __init__(self, state_size, action_size, load=False, filename=''):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = Replay_buffer(state_size, action_size, size=500)
        self.learning_rate = 0.05 # default learning rate   
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        self.best_move_smoothing = 0.1 # when several next best moves are roughly equal, choose randomly
        self.randocount = 0
        self.NNcount = 0
        self.epsiloncount = 0
        self.movecount = 0
        self.bummers = []
        if load == True:
          self.model = load_model(filename)
#model design:
#       input layer: size of state (27)
#       hidden layers
#       output layer: size of action list (5)        

    def create(self, state_dim, action_dim, hidden_layers=13, hidden_dim=(64, 64, 64), debug=False):
        i = Input(shape=(state_dim,))
        x = i
        for k in range(hidden_layers):
            x = Dense(hidden_dim[k], activation='relu')(x)
        x = Dense(action_dim)(x) # output layer
        self.model = Model(i, x) 
        self.model.compile(optimizer='adam',
                           loss='mse',
                           metrics=['accuracy'])
        if debug:
            print((self.model.summary()))
        return self.model
    
    def model_save(self, filename):
      self.model.save(filename)

    def pred(self, state):
        return self.model.predict(state)

    def act_learner(self, state, player): # state is the current board
        self.movecount += 1
        if np.random.rand() <= self.epsilon:
            self.epsiloncount += 1
            return robot_player_learner(state, player)
        sf = np.zeros((1,9))
        sf[0] = state.board.flatten()

        act = self.model.predict(sf) 
 
        m = get_best_legal_move(state, act[0], self.best_move_smoothing, debug=False)
        self.NNcount += 1
        return m            
    
    def act_trainer(self, state, player): # state is the current board
        self.movecount += 1
        if np.random.rand() <= self.epsilon:
            self.epsiloncount += 1
            return robot_player_teacher(state, player)
        sf = np.zeros((1,9))
        sf[0] = state.board.flatten()

        act = self.model.predict(sf) 
 
        m = get_best_legal_move_with_checking(state, act[0], self.best_move_smoothing, debug=False)
        self.NNcount += 1
        return m            
    
    def update_replay_memory(self, state, action, reward, next_state, done):
        self.memory.store(state, action, reward, next_state, done)
        
    def printmini2(self, mini, t1, t2, t3, t4):
        print("\n")
        print("         current states      a    r              next state        d   tgt             predict(states) pre train                                       Target_full                                                      predict(states) post train                      ")
        print("---------------------------- - ------ ---------------------------- - ------ -------------------------------------------------------------- -------------------------------------------------------------- --------------------------------------------------------------")
        for i in range(len(mini["s"])):
            print("minibatch print def in here")
        print("-----------------------------------\n")
            

    def replay_one_game(self, batch_size=32, debug=False):
        #sample a batch of data from the replay memory
        if self.memory.size < batch_size:
            return
        minibatch = self.memory.sample_batch(batch_size)
        states = minibatch['s']
        actions = minibatch['a']
        rewards = minibatch['r']
        next_states = minibatch['s2']
        done = minibatch['d']
# chanaging the rewards application to happen at end of each game - in the play one game function
        target = rewards # + (1 - done) * self.gamma * future_rwds
        target[done] = rewards[done] # if there are any "done" then replace the target with the reward

        target_full = self.model.predict(states)
        predict_pre = self.model.predict(states)
        target_full[np.arange(len(actions)), actions] = target
        
        self.model.train_on_batch(states, target_full)

        if debug == True:
         predict_post = self.model.predict(states)
         self.printmini2(minibatch, target, predict_pre, target_full, predict_post)

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        else:
            self.epsilon = self.epsilon_min
            

class Replay_buffer:
  def __init__(self, obs_dim, act_dim, size):
    self.current_state_buf = np.zeros([size, obs_dim], dtype = np.float32)  # board state pre move
    self.next_state_buf = np.zeros([size, obs_dim], dtype = np.float32)  # board state post move
    self.action_buf = np.zeros(size, dtype = np.uint8)  # board state pre move
    self.reward_buf = np.zeros(size, dtype = np.float32)  # rewards
    self.done_buf = np.zeros(size, dtype = np.uint8)  # board state pre move
    self.ptr, self.size, self.max_size = 0, 0, size

  def store(self, current_state, action, reward, next_state, done):
    self.current_state_buf[self.ptr] = current_state
    self.next_state_buf[self.ptr] = next_state
    self.action_buf[self.ptr] = action
    self.reward_buf[self.ptr] = reward
    self.done_buf[self.ptr] = done
    self.ptr = (self.ptr+1) % self.max_size
    self.size = min(self.size+1, self.max_size)
#    print("Store: ptr=",self.ptr, " size:",self.size)
      
  def sample_batch(self, batch_size=32):  # need to make sure we don't split an EPISODE tho unless we distribute rewards
    idxs = np.random.randint(0, self.size, size=batch_size)
    return dict(s=self.current_state_buf[idxs],
                a=self.action_buf[idxs],
                r=self.reward_buf[idxs],
                s2=self.next_state_buf[idxs],
                d=self.done_buf[idxs])

"""
Miscellaneous helper functions and definitions
"""

#############################################################
## Deck
##
#############################################################
deck_value = {"AH": 5, "KH": 4, "QH": 3, "JH": 2, "TH": 1, \
                   "AD": 5, "KD": 4, "QD": 3, "JD": 2, "TD": 1, \
                   "AS": 5, "KS": 4, "QS": 3, "JS": 2, "TS": 1, \
                   "AC": 5, "KC": 4, "QC": 3, "JC": 2, "TC": 1, \
                   "--": 0}

deck_decode = ["AH", "KH", "QH", "JH", "TH", \
               "AD", "KD", "QD", "JD", "TD", \
               "AS", "KS", "QS", "JS", "TS", \
               "AC", "KC", "QC", "JC", "TC", \
               "--"]
class Deck():
    def __init__(self, cards_in_deck=DECK_SIZE):
        self.cards_in_deck = cards_in_deck

    def create(self):
        self.deck = np.arange(self.cards_in_deck, dtype=int )
        return self.deck

    def deal(self, num_hands=4, cards_per_hand=5, number_of_shuffles=1):
      hands = np.zeros((num_hands,cards_per_hand), dtype=int)
      idx = list(range(0, self.cards_in_deck))
      for i in range(number_of_shuffles):
        random.shuffle(idx)
      for i in range(cards_per_hand):
        for j in range(num_hands):
          hands[j][i] = idx[i*4+j]
      return hands

def suit(card):
    return deck_decode[card][-1]

def face(card):
    return deck_decode[card]

def is_trump(card, trump):
    return suit(card) == trump

def value(card):
    return deck_value[deck_decode[card]]

def pick_trump():
  suits = ['H', 'D', 'C', 'S']
  trump = suits[random.randint(0,3)]
  return trump

def show_hand(hand):
  h = []
  for card in hand:
    h.append(face(card))
  return h

def hands_print(hands, trump, dealer):
  print("Play0    Play1    Play2    Play3\n======   ======   ======   ======")
  for j in range(5):
    print("%3s: %1d   %3s: %1d   %3s: %1d   %3s: %1d" % (face(hands[0][j]), value(hands[0][j]), \
                                                         face(hands[1][j]), value(hands[1][j]), \
                                                         face(hands[2][j]), value(hands[2][j]), \
                                                         face(hands[3][j]), value(hands[3][j])))
  print("Trump: ", trump)
  print("Dealer: ", dealer)


def card_compare(card1, card2, trump):
    suit1 = suit(card1)
    suit2 = suit(card2)
    val1 = value(card1)
    val2 = value(card2)
    
    if is_trump(card1, trump) and (not is_trump(card2, trump)): # card1 was trump, card2 not card 1wins
      return card1
    if is_trump(card2, trump) and (not is_trump(card1, trump)): # card2 was trump, card1 not, so card2 wins  
      return card2
    if is_trump(card1, trump) and is_trump(card2, trump): # both trump, higher value wins
      if val1 >= val2:
        return card1
      else:
        return card2
    if suit1 != suit2:  # no trump - id card2 follow suit?
      return card1        # no, card1 wins
    else:                 # followed suit, so... compare value
      if val2 > val1:     # biggest card wins... card1 unless card2 is bigger
        return card2
      else:
         return card1
    print("ERROR IN card_compare: ", card1, card2)
    return -1          

def who_won_round(trump, round_state, play_order, debug=0):
  # evaluate cards played to determine winner
  # if trump played, highest trump wins
  # if no_trump played, highest of lead suit played wins
  best_card = round_state[0]
  best_player = play_order[0]
  for i in range(len(round_state)):
    if debug > 2:
      print("player ", play_order[i], " played ", face(round_state[i]))
    test_card = card_compare(best_card, round_state[i], trump)
    if test_card != best_card:
      best_card = test_card
      best_player = play_order[i]
  return best_player, best_card

def what_is_winning_round(trump, round_state, debug=0):
  # evaluate cards played to determine current winning card
  # if trump played, highest trump wins
  # if no_trump played, highest of lead suit played is winning

  best_card = round_state[0]
  if len(round_state) == 1:
    return best_card
  if debug > 3: 
    print("what is winning: ", round_state, len(round_state))
  for i in range(1, len(round_state)):
    test_card = card_compare(best_card, round_state[i], trump)
    if test_card != best_card:
      best_card = test_card
  return best_card

"""
MAIN ACTION SECTION:
  - play_one_card
  - play_one_hand
  - play_one_game
"""
def play_one_card_bot(hands, trump, player, round_state, debug=0):
  # if am i lead?
  #   play winner or slough? 
  # else can i follow suit?
  # else do I slough... or trump!
  
  # preprocess my hand
    mycards = np.where(hands[player] != CARD_PLAYED)
    playable = hands[player][mycards]
    card_face = []
    card_value = []
    card_suit = []
    card_trump = []
    card_index = []
    
    for card in playable:
      card_face.append(face(card))
      card_value.append(value(card))
      card_suit.append(suit(card))    
      card_trump.append(is_trump(card, trump))
      card_index.append(card)

    if len(round_state) == 0:  # i'm lead...
      if debug > 3: 
        print("I'm lead, my cards: ", show_hand(playable))
      # play highest non-trump
      idx = [i for i in range(len(card_value)) ]
      high = 0
      high_idx = 0
      card_idx = 0
      if len(idx) > 0: # we can follow suit
        if debug > 3:
          print("Following suit...", idx)
        for i in idx:
          if high < card_value[i]:
              high = card_value[i]
              high_idx = i    
      play = card_index[high_idx]
      hands[player][mycards[0][high_idx]] = CARD_PLAYED
      suit_to_follow = suit(play)

    else:
      suit_to_follow = suit(round_state[0])
      if debug > 3:
        print("I'm follower, trump is: ", trump, "suit to follow is: ", suit_to_follow, "my cards: ", show_hand(playable))
      # play highest non-trump in suit
      # check to see winning card in current play
      current_winning_card = what_is_winning_round(trump, round_state)
      if debug > 3:
        print("Current winning card: ", face(current_winning_card), is_trump(current_winning_card, trump))
      #if current winning card is trump:
      # if we have to follow suit, go low
      # if we have to slough go short suit
      # if we can over-trump, do it
      follow_go_low = False
      over_trump = False

      if is_trump(current_winning_card, trump):
        follow_go_low = True
        over_trump = True

      idx = [i for i in range(len(playable)) if card_suit[i] == suit_to_follow ]
      high = 0
      low = 100
      card_idx = 0
      if len(idx) > 0: # we can follow suit
        if debug > 3:
          print("Following suit...", idx)
        for i in idx:
          if high < card_value[i]:
              high = card_value[i]
              high_idx = i    
          if low > card_value[i]:
              low = card_value[i]
              low_idx = i
        # we have our highest and lowest suit followers
        if debug > 3:
          print("high/low follwer: ", face(card_index[high_idx]), face(card_index[low_idx]))

        if value(current_winning_card) > value(card_index[high_idx]): # we can't beat the current winning card, so go low in following suit
          follow_go_low = True

        if follow_go_low:
          card_idx = low_idx
          if debug > 4:
            print("going low")
        else:
          card_idx = high_idx
          if debug > 4:
            print("going high")

      else: # can't follow suit... can we trump it?
        idx = [i for i in range(len(card_trump)) if card_trump[i] == True]
        if len(idx) > 0: # we can trump
          if len(idx) == 1: # we only have one trump, so use it
            card_idx = idx[0]
          else:  # we have more than one trump - choose

            high = 0
            low = 100
            card_idx = 0
            for i in idx: # find my high and low trump
              if high < card_value[i]:
                high = card_value[i]
                high_idx = i
              if low > card_value[i]:
                low = card_value[i]
                low_idx = i  
            if over_trump:
                card_idx = high_idx
                if debug > 4:
                  print("Over Trump it!", card_idx)
            else: # play low trump
                 card_idx = low_idx
                 if debug > 4:
                   print("Under Trump it!", card_idx)
        else:  # no trump, let's slough a loser
          idx = [i for i in range(len(playable))] # get list of cards
          if len(idx) > 0: # we can slough
              low = 100
              card_idx = 0
              for i in idx: # play lowest slough
                if low > card_value[i]:
                   low = card_value[i]
                   card_idx = i

      play = card_index[card_idx]
      if debug > 2:
        print("Playing: ", face(card_index[card_idx]))
      hands[player][mycards[0][card_idx]] = CARD_PLAYED
    return play, hands



def play_one_card(hands, trump, player, round_state, debug=0):
  # if am i lead?
  #   play winner or slough? 
  # else can i follow suit?
  # else do I slough... or trump!
  
  # preprocess my hand
    mycards = np.where(hands[player] != CARD_PLAYED)
    playable = hands[player][mycards]
    card_face = []
    card_value = []
    card_suit = []
    card_trump = []
    card_index = []
    
    for card in playable:
      card_face.append(face(card))
      card_value.append(value(card))
      card_suit.append(suit(card))    
      card_trump.append(is_trump(card, trump))
      card_index.append(card)

    if len(round_state) == 0:  # i'm lead...
      if debug > 4: 
        print("I'm lead, my cards: ", show_hand(playable))
      # play highest non-trump
      idx = [i for i in range(len(card_value)) ]
      high = 0
      high_idx = 0
      card_idx = 0
      if len(idx) > 0: # we can follow suit
        if debug > 4:
          print("Following suit...", idx)
        for i in idx:
          if high < card_value[i]:
              high = card_value[i]
              high_idx = i    
      play = card_index[high_idx]
      hands[player][mycards[0][high_idx]] = CARD_PLAYED
      suit_to_follow = suit(play)

    else:
      suit_to_follow = suit(round_state[0])
      if debug > 4:
        print("I'm follower, trump is: ", trump, "suit to follow is: ", suit_to_follow, "my cards: ", show_hand(playable))
      # play highest non-trump in suit
      # check to see winning card in current play
      current_winning_card = what_is_winning_round(trump, round_state)
      if debug > 4:
        print("Current winning card: ", face(current_winning_card), is_trump(current_winning_card, trump))
      #if current winning card is trump:
      # if we have to follow suit, go low
      # if we have to slough go short suit
      # if we can over-trump, do it
      follow_go_low = False
      over_trump = False

      if is_trump(current_winning_card, trump):
        follow_go_low = True
        over_trump = True

      idx = [i for i in range(len(playable)) if card_suit[i] == suit_to_follow ]
      high = 0
      low = 100
      card_idx = 0
      if len(idx) > 0: # we can follow suit
        if debug > 4:
          print("Following suit...", idx)
        for i in idx:
          if high < card_value[i]:
              high = card_value[i]
              high_idx = i    
          if low > card_value[i]:
              low = card_value[i]
              low_idx = i
        # we have our highest and lowest suit followers
        if debug > 4:
          print("high/low follwer: ", face(card_index[high_idx]), face(card_index[low_idx]))

        if value(current_winning_card) > value(card_index[high_idx]): # we can't beat the current winning card, so go low in following suit
          follow_go_low = True

        if follow_go_low:
          card_idx = low_idx
          if debug > 4:
            print("going low")
        else:
          card_idx = high_idx
          if debug > 4:
            print("going high")

      else: # can't follow suit... can we trump it?
        idx = [i for i in range(len(card_trump)) if card_trump[i] == True]
        if len(idx) > 0: # we can trump
          if len(idx) == 1: # we only have one trump, so use it
            card_idx = idx[0]
          else:  # we have more than one trump - choose

            high = 0
            low = 100
            card_idx = 0
            for i in idx: # find my high and low trump
              if high < card_value[i]:
                high = card_value[i]
                high_idx = i
              if low > card_value[i]:
                low = card_value[i]
                low_idx = i  
            if over_trump:
                card_idx = high_idx
                if debug > 4:
                  print("Over Trump it!", card_idx)
            else: # play low trump
                 card_idx = low_idx
                 if debug > 4:
                   print("Under Trump it!", card_idx)
        else:  # no trump, let's slough a loser
          idx = [i for i in range(len(playable))] # get list of cards
          if len(idx) > 0: # we can slough
              low = 100
              card_idx = 0
              for i in idx: # play lowest slough
                if low > card_value[i]:
                   low = card_value[i]
                   card_idx = i

      play = card_index[card_idx]
      if debug > 4:
        print("Playing: ", face(card_index[card_idx]))
      hands[player][mycards[0][card_idx]] = CARD_PLAYED
    return play, hands

def play_one_game(deck, dealer, num_players=4, debug=0):
  # dealer = passed in from overall main game
  # instantiate State for each player
  # deal cards
  # pick trump
  # lead = (dealer + 1) % 4
  # for each round (5), for each player (4) play_one_card
  # rotate the dealer for the next round

  hands = deck.deal(num_hands=4, cards_per_hand=5, number_of_shuffles=2)
  trump = pick_trump()
  playerstate = [0] * num_players

  for i in range(num_players):
    playerstate[i] = State() # initialize state object for each player
    playerstate[i].mycards = hands[i]
    playerstate[i].trump = trump

  if debug > 4:
    hands_print(hands, trump, dealer)
  if debug > 1:  
    for i in range(num_players):
      playerstate[i].print()

  tricks = [0] * num_players
  lead = (dealer + 1) % num_players # initial lead to dealers left
  
  for round in range(5):
    round_state = []
    round_order = []
    for p in range(lead, lead+num_players):
      player = p % num_players
      if debug > 4:
        print("ROUND: ", round, "Player: ", player)
      play, hands = play_one_card(hands, trump, player, round_state)

      if debug > 4:
        print("Player %1d plays %3s" % (player, face(play)))
      round_state.append(play)
      round_order.append(player)
      faces = []
      for i in range(len(round_state)):
        faces.append(face(round_state[i]))
      if debug > 4:
          print("Played so far: ", faces)
          print("Round Order:   ", round_order)
          print("-------------------")
      winner, c = who_won_round(trump, round_state, round_order)  
    if debug > 4:
      print("Trump was: ", trump)
      print("winning card was: ", face(c), "played by: ", winner)
      print("====================================\n")
    tricks[winner] += 1
    lead = winner
  if debug > 2:
    print("----- End of Game Results -----")
    for i in range(num_players):
      print("Player ", i, "took ", tricks[i], "tricks.")
    print("-------------------------------")

  return tricks, round_state

# %%
def play_one_tournament(winning_score=10, num_players=4, debug=0):
  deck = Deck(DECK_SIZE)
  score = [0] * num_players
  dealer = np.random.randint(0,num_players)  # start each tournament with random dealer
  games_played_this_tournament = 0

  while True:
    if (max(score) >= winning_score): 
      # ensure no ties
      w = max(score)
      if score.count(w) == 1:
        break

    deck.create()  
    tricks, played = play_one_game(deck, dealer, num_players, debug)
    for i in range(num_players):
      score[i] += tricks[i]  
    dealer = (dealer + 1) % num_players
    games_played_this_tournament += 1

  if debug > 0:
        print("\n========= End of Tournament Score ========Games: ", games_played_this_tournament)
        for i in range(num_players):
          print("Player ", i, "Score ", score[i])
        print("\n===========================================")

  return score, games_played_this_tournament

# %%
###############################
# Testing loop
################################
#game hyperparameters
num_players = 4
win_score = 15
debug_level = 2

#stats initialization
scores = [0] * num_players    
tournaments = 1000
tournaments_won = [0] * num_players
tricks_in_tournament = 0
total_games_played = 0

for i in range(tournaments):    
    score, games_played_this_tournament = play_one_tournament(win_score, num_players, debug=debug_level)
    for j in range(num_players):
      scores[j] += score[j]
    tricks_in_tournament += sum(score)
    tournament_winner = np.argmax(score)
    tournaments_won[tournament_winner] += 1
    total_games_played += games_played_this_tournament

    if ((i + 1) % 1000) == 0:
      print("\n========= OVERALL Tournament wins %4d/%4d ==========" % (i+1, tournaments))
      print("Player Wins   Win pct")
      for j in range(num_players):
        print("  %1d    %5d    %2.2f" %  (j+1, tournaments_won[j], tournaments_won[j]/sum(tournaments_won)))
      print("\n========= OVERALL Tricks taken  out of %4d==========" % (sum(scores)))
      print("Player Hands  Win pct")
      for j in range(num_players):
        print("  %1d    %5d    %2.2f" %  (j+1, scores[j], scores[j]/sum(scores)))
      print("\n=========================================")

      print(" Total tricks played: ", tricks_in_tournament)
      print(" Total games played: ", total_games_played)
      print(" Total tournaments played: ", sum(tournaments_won))
      print(" Average tricks per Tournament: ", tricks_in_tournament / sum(tournaments_won))
      print(" Average games per Tournament: ", total_games_played / sum(tournaments_won))
      print(" Average tricks per game: ", tricks_in_tournament / total_games_played)
# Out:
# Streaming output truncated to the last 5000 lines.
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'JS', 'QS', 'JH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KS', 'QH', 'QD', 'TS', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AH', 'TD', 'TH', 'JC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KC', 'AC', 'AD', 'KH', 'AS']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  11
# Player  0 Score  13
# Player  1 Score  13
# Player  2 Score  14
# Player  3 Score  15
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JH', 'AH', 'JS', 'TC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'KS', 'AD', 'QC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AS', 'AC', 'TS', 'JD', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TH', 'KD', 'QS', 'KC', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AC', 'KD', 'QD', 'AH', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'TC', 'KS', 'JS', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'JH', 'JC', 'QC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AS', 'JD', 'QS', 'AD', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KS', 'KD', 'TC', 'JH', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'TS', 'TD', 'KH', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QH', 'AC', 'TH', 'QS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AS', 'KC', 'JD', 'JS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TD', 'TC', 'JC', 'KC', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JS', 'QH', 'AH', 'JH', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AS', 'AC', 'JD', 'TS', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QS', 'KD', 'TH', 'AD', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'AC', 'TS', 'TC', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AH', 'KS', 'JS', 'KH', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JH', 'TH', 'JC', 'AD', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KD', 'QS', 'QD', 'QC', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KS', 'JC', 'AS', 'AD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'QH', 'JH', 'KC', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AC', 'KH', 'TS', 'KD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JS', 'QC', 'QD', 'TH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TC', 'QC', 'QD', 'QS', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KS', 'KH', 'AC', 'JS', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'KC', 'KD', 'TS', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'JD', 'AS', 'QH', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'TH', 'KC', 'QS', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JH', 'TD', 'JS', 'JC', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AC', 'QC', 'AS', 'QD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'QH', 'AD', 'AH', 'TS']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  8
# Player  0 Score  4
# Player  1 Score  8
# Player  2 Score  17
# Player  3 Score  11
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'QD', 'KC', 'TC', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'JH', 'AC', 'AH', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'TD', 'JC', 'JD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TS', 'TH', 'KD', 'AS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'KH', 'AC', 'KS', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QD', 'QC', 'JH', 'QS', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KD', 'QH', 'TD', 'JC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AD', 'KC', 'TH', 'JD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KD', 'AC', 'QC', 'TS', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QS', 'AD', 'QH', 'TC', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TD', 'JS', 'KH', 'TH', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'JD', 'QD', 'KS', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QC', 'JS', 'TC', 'AC', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QS', 'JH', 'AD', 'JC', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'JD', 'TD', 'KC', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'KD', 'QD', 'AS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JH', 'KH', 'AD', 'KD', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AC', 'JC', 'TC', 'AS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KC', 'QD', 'QS', 'TH', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AH', 'TD', 'QH', 'JS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JD', 'AH', 'AD', 'JS', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'TH', 'KC', 'QS', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AS', 'TS', 'QC', 'QH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QD', 'TC', 'KH', 'KS', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'KS', 'KH', 'TC', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'QS', 'QD', 'TD', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'TS', 'JC', 'TH', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AS', 'JD', 'KC', 'QH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KC', 'AS', 'KS', 'QH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AD', 'QD', 'TD', 'QS', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'QC', 'AH', 'TH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'JS', 'KH', 'JH', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TD', 'AH', 'KC', 'JH', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JC', 'AC', 'QS', 'AS', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'TH', 'QH', 'KH', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'JS', 'TC', 'JD', 'KD']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  9
# Player  0 Score  13
# Player  1 Score  16
# Player  2 Score  5
# Player  3 Score  11
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QC', 'TC', 'QS', 'KS', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TS', 'AC', 'JS', 'AS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JC', 'QH', 'KC', 'TH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'JD', 'JH', 'KD', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'QS', 'JD', 'JH', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QH', 'TS', 'QC', 'AC', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TD', 'JS', 'KC', 'KH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QD', 'AS', 'TC', 'KD', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QC', 'KS', 'QH', 'KH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TS', 'TD', 'AH', 'KC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'TC', 'TH', 'KD', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QD', 'AC', 'JC', 'JD', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'TD', 'JS', 'JD', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AH', 'AC', 'KS', 'QC', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QH', 'KD', 'QD', 'AD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'JH', 'QS', 'JC', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'TS', 'QC', 'TH', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QS', 'AD', 'JH', 'JC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KH', 'AS', 'AH', 'TC', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JS', 'JD', 'QD', 'KD', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KD', 'TC', 'KH', 'QS', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'AS', 'AH', 'KC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JH', 'TS', 'KS', 'QH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'TH', 'QD', 'AC', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JH', 'JS', 'KH', 'TH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AH', 'TS', 'KD', 'JD', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'JC', 'KC', 'AD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KS', 'QD', 'QC', 'QH', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AS', 'TD', 'AH', 'JH', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TC', 'AD', 'QH', 'KC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'QD', 'TH', 'KS', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JS', 'KD', 'JC', 'QS', 'JD']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  8
# Player  0 Score  6
# Player  1 Score  16
# Player  2 Score  8
# Player  3 Score  10
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KD', 'TC', 'QC', 'JS', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QD', 'TH', 'AD', 'JH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TD', 'JC', 'AC', 'KS', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TS', 'KC', 'AS', 'AH', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'QH', 'KD', 'TC', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JD', 'QD', 'AC', 'KS', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'TD', 'JS', 'QS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AD', 'KH', 'TS', 'TH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TD', 'JC', 'AH', 'KS', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AS', 'JD', 'KC', 'JS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QD', 'AC', 'AD', 'TH', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JH', 'KD', 'TS', 'TC', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QS', 'JS', 'JD', 'TD', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'KS', 'KD', 'TS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JH', 'KC', 'TC', 'QH', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AS', 'JC', 'QC', 'QD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TC', 'AH', 'KS', 'QD', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KD', 'KC', 'TS', 'AD', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JS', 'AS', 'AC', 'QH', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'QC', 'JD', 'QS', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QH', 'JH', 'AD', 'QD', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AH', 'TS', 'TH', 'KD', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TC', 'QS', 'AC', 'QC', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TD', 'KS', 'JD', 'AS', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'TS', 'JS', 'AC', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QD', 'AD', 'KH', 'TH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TC', 'JC', 'KD', 'JH', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'KC', 'AS', 'QH', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JC', 'KD', 'KH', 'AS', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'KC', 'QD', 'JS', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KS', 'QS', 'QH', 'AD', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'JD', 'JH', 'TS', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'JC', 'AS', 'TD', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AH', 'QS', 'KD', 'KS', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TS', 'QD', 'JS', 'JD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QH', 'JH', 'TH', 'AC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'AH', 'KD', 'KH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'TC', 'JC', 'KC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QD', 'AC', 'TH', 'AS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JD', 'TS', 'JS', 'QH', 'QC']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  10
# Player  0 Score  10
# Player  1 Score  13
# Player  2 Score  15
# Player  3 Score  12
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JD', 'TS', 'TD', 'JC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'TH', 'AD', 'AH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'JH', 'AC', 'QC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QH', 'TC', 'AS', 'QS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JS', 'TH', 'TC', 'AD', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AH', 'AC', 'JH', 'JC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KD', 'QH', 'TS', 'JD', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KS', 'KH', 'QC', 'QS', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'KD', 'JS', 'KS', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JC', 'AS', 'AC', 'KH', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'AH', 'QD', 'QS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AD', 'JD', 'TD', 'TH', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'TH', 'KC', 'QD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AD', 'KS', 'TD', 'AS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AH', 'QS', 'KD', 'QH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'JH', 'AC', 'JC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QC', 'KD', 'AH', 'QH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TS', 'AD', 'KC', 'KH', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'QS', 'JC', 'QD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AS', 'JD', 'AC', 'KS', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JD', 'QS', 'KS', 'AD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TC', 'KC', 'QD', 'KH', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AC', 'AS', 'QC', 'JC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'TS', 'KD', 'AH', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'JC', 'TC', 'TS', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AD', 'QD', 'QC', 'AH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AS', 'AC', 'QS', 'TH', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KD', 'TD', 'JS', 'KH', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'AD', 'QH', 'JC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JD', 'TD', 'JS', 'QD', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AC', 'KS', 'TH', 'TS', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TC', 'AS', 'KH', 'QS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'JH', 'AH', 'AC', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'KH', 'TD', 'TC', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KS', 'QD', 'KC', 'JS', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'QC', 'QS', 'KD', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TH', 'TC', 'KH', 'KS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JD', 'TD', 'TS', 'KC', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'AD', 'QC', 'JC', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AS', 'QD', 'JS', 'KD', 'JH']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  10
# Player  0 Score  10
# Player  1 Score  15
# Player  2 Score  8
# Player  3 Score  17
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QH', 'TC', 'AC', 'KH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QC', 'AS', 'AH', 'KC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'KD', 'QS', 'TH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'TS', 'QD', 'KS', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AS', 'TD', 'TS', 'AC', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JD', 'QS', 'KS', 'QC', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KH', 'KD', 'QH', 'AD', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'TC', 'JS', 'TH', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AD', 'AC', 'JD', 'KD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'KS', 'JH', 'KC', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QS', 'TH', 'TD', 'KH', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QH', 'AS', 'QC', 'QD', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KH', 'AS', 'QH', 'AD', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KS', 'QS', 'KD', 'AH', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'TH', 'TS', 'AC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QC', 'TC', 'TD', 'JC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KD', 'KS', 'AS', 'TH', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QC', 'JC', 'TC', 'JH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KH', 'QH', 'AD', 'AC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JD', 'KC', 'QS', 'AH', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KS', 'QC', 'AH', 'QH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'QD', 'QS', 'KD', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'AD', 'JH', 'JS', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TC', 'AC', 'KH', 'TD', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AS', 'KC', 'QH', 'TH', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AD', 'KH', 'JC', 'TD', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'QS', 'TS', 'AC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QD', 'KS', 'JD', 'KD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'AH', 'KC', 'KH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QC', 'QD', 'TC', 'AC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'KS', 'QH', 'JH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'AS', 'JD', 'AD', 'KD']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  8
# Player  0 Score  15
# Player  1 Score  11
# Player  2 Score  6
# Player  3 Score  8
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TS', 'QD', 'JD', 'QS', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TH', 'JC', 'KC', 'JS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KH', 'TC', 'AD', 'QC', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AS', 'KD', 'TD', 'QH', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'AH', 'QC', 'TS', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'KD', 'AC', 'QS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'TC', 'QH', 'JD', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'JH', 'JC', 'AS', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TD', 'AC', 'JD', 'TH', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QC', 'AH', 'JC', 'KC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QS', 'TS', 'AD', 'KH', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AS', 'KS', 'QH', 'KD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'QH', 'TH', 'QS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'JD', 'AS', 'JC', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'AC', 'KD', 'TD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KS', 'TC', 'AD', 'TS', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KS', 'QC', 'AS', 'TD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TS', 'AD', 'QD', 'TH', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AC', 'KD', 'JH', 'JS', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'JD', 'QS', 'TC', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TD', 'AD', 'TH', 'JS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'AS', 'KH', 'QS', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'QD', 'AH', 'QC', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TC', 'JC', 'QH', 'JH', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QH', 'AD', 'TS', 'JH', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QD', 'AC', 'QC', 'KD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JD', 'TH', 'JS', 'KH', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AS', 'TD', 'KC', 'KS', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TH', 'QD', 'AH', 'KD', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AS', 'JD', 'TD', 'JC', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AC', 'TS', 'JH', 'AD', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'KH', 'QS', 'KS', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QS', 'QD', 'JS', 'AS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KS', 'JC', 'AH', 'TC', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'KC', 'QH', 'AC', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'TH', 'KH', 'AD', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AD', 'KH', 'JD', 'TH', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JC', 'JH', 'AS', 'JS', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QD', 'KD', 'QH', 'QC', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AC', 'QS', 'TD', 'TC', 'AH']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  10
# Player  0 Score  11
# Player  1 Score  10
# Player  2 Score  15
# Player  3 Score  14
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QH', 'JH', 'AS', 'KS', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TS', 'QD', 'KD', 'JS', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JC', 'TC', 'AH', 'TD', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KH', 'KC', 'TH', 'AD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QH', 'TC', 'AH', 'QS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'KC', 'AC', 'TD', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KH', 'AD', 'QD', 'TS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TH', 'JS', 'KD', 'AS', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'KD', 'AD', 'TC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JS', 'QH', 'KS', 'JD', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KH', 'JH', 'TD', 'KC', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AC', 'TH', 'AH', 'AS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'QD', 'KH', 'TD', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KD', 'KS', 'JS', 'AH', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'TH', 'AD', 'AS', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QH', 'TC', 'QS', 'JC', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TC', 'AC', 'KH', 'JC', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TH', 'TD', 'JD', 'JS', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'QS', 'KD', 'KC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KS', 'QC', 'AS', 'AH', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JC', 'TD', 'TC', 'JH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TS', 'JD', 'TH', 'KD', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QC', 'AS', 'KS', 'JS', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'QD', 'KC', 'KH', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'KD', 'KS', 'AD', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QC', 'AS', 'QH', 'JH', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AC', 'KC', 'JD', 'AH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'TC', 'QS', 'TS', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'QC', 'QH', 'JC', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'KH', 'QS', 'KS', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'TH', 'JS', 'JD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TD', 'JH', 'AD', 'TC', 'TS']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  8
# Player  0 Score  5
# Player  1 Score  11
# Player  2 Score  15
# Player  3 Score  9
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'JS', 'TH', 'TC', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TS', 'JC', 'AC', 'TD', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'QS', 'JD', 'QD', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AH', 'QC', 'QH', 'AS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KC', 'JH', 'TS', 'QD', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'AS', 'QH', 'AC', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TD', 'JS', 'AH', 'JD', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QS', 'QC', 'TC', 'JC', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TS', 'KS', 'QS', 'AS', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TH', 'JS', 'KD', 'TC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'AH', 'QC', 'AD', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TD', 'JC', 'KH', 'AC', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KS', 'JH', 'TC', 'KC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'KH', 'QH', 'AC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QC', 'JD', 'QD', 'AS', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TS', 'QS', 'JC', 'AH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KS', 'JH', 'JC', 'JD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QH', 'KC', 'QC', 'QD', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'JS', 'KD', 'AD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QS', 'AS', 'TD', 'KH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KS', 'JC', 'AD', 'KH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TS', 'AC', 'TC', 'QS', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'JD', 'JH', 'TD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'QD', 'AS', 'KD', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QD', 'AD', 'QH', 'TS', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'AC', 'KD', 'TC', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'AS', 'JS', 'KS', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'QS', 'QC', 'AH', 'JD']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  7
# Player  0 Score  4
# Player  1 Score  7
# Player  2 Score  9
# Player  3 Score  15
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JH', 'QD', 'JC', 'AD', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AC', 'KD', 'QS', 'AH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TD', 'KC', 'JS', 'QC', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KS', 'TC', 'TS', 'KH', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'TS', 'TH', 'KC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JC', 'KD', 'AD', 'TD', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'AS', 'JH', 'QH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'QS', 'JS', 'TC', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'JC', 'TS', 'AS', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AD', 'QH', 'AH', 'JS', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KH', 'KD', 'KS', 'QD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JD', 'AC', 'QC', 'QS', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'TC', 'KS', 'AD', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QS', 'AS', 'JH', 'KD', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JC', 'QH', 'TD', 'TH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'QD', 'KC', 'QC', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'KS', 'TH', 'JD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AD', 'AS', 'KC', 'TC', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JS', 'KH', 'TD', 'QH', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QD', 'AC', 'JH', 'KD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AH', 'KD', 'QC', 'JD', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AD', 'KS', 'TS', 'KC', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JH', 'JS', 'QH', 'AC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'TC', 'TH', 'QS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'AH', 'TC', 'TD', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TS', 'AC', 'AD', 'KS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JD', 'JC', 'QS', 'TH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'JH', 'AS', 'KC', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AD', 'QD', 'TD', 'KH', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'KS', 'TS', 'AS', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AC', 'JS', 'QH', 'TC', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AH', 'TH', 'JD', 'QS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TD', 'JD', 'TH', 'QH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'AH', 'KS', 'TS', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'AS', 'AC', 'AD', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KD', 'KC', 'QC', 'JS', 'TC']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  9
# Player  0 Score  12
# Player  1 Score  16
# Player  2 Score  7
# Player  3 Score  10
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KS', 'QS', 'AS', 'TC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QH', 'TD', 'AC', 'KH', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'JC', 'JD', 'JS', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QD', 'KD', 'QC', 'AH', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JD', 'QC', 'JS', 'JH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'TS', 'KD', 'QH', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TD', 'KH', 'TH', 'KS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'JC', 'QD', 'TC', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QD', 'JH', 'KS', 'AS', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'KH', 'TH', 'AC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JS', 'QS', 'AH', 'JC', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'KD', 'QH', 'TC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TD', 'QS', 'KC', 'JS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QC', 'AC', 'AH', 'AD', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TC', 'KH', 'JH', 'TH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QH', 'KD', 'TS', 'KS', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'QH', 'AC', 'JS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'KC', 'JD', 'AH', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'KH', 'TD', 'QS', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AD', 'KS', 'AS', 'QC', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AS', 'JD', 'QH', 'KC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TC', 'QD', 'KD', 'JC', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'JH', 'JS', 'QC', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'TD', 'KS', 'TH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QS', 'AS', 'JD', 'TH', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JS', 'AC', 'JH', 'QD', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'KS', 'TS', 'AH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QC', 'JC', 'AD', 'QH', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TC', 'KS', 'TH', 'AS', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'AH', 'TD', 'KH', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JC', 'JD', 'TS', 'KC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'QD', 'QH', 'KD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'AC', 'JH', 'TC', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'QC', 'AS', 'TS', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QD', 'KD', 'AH', 'TH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QH', 'AD', 'KC', 'KS', 'QS']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  9
# Player  0 Score  9
# Player  1 Score  15
# Player  2 Score  10
# Player  3 Score  11
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QD', 'QH', 'JD', 'KD', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'TC', 'AC', 'AS', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'JC', 'QC', 'KC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JS', 'AH', 'QS', 'KS', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AC', 'AS', 'JH', 'TH', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'QD', 'QH', 'KS', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KD', 'AH', 'JS', 'QS', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'TS', 'QC', 'TC', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'JD', 'JH', 'AC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KD', 'QS', 'JC', 'AD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JS', 'QD', 'KH', 'QC', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TS', 'AH', 'AS', 'QH', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QH', 'AS', 'JC', 'AD', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KS', 'TC', 'KH', 'JH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QC', 'KD', 'KC', 'TH', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JS', 'AC', 'TS', 'AH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AH', 'KD', 'JD', 'KH', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QH', 'TH', 'JH', 'AD', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KS', 'TC', 'TD', 'QS', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'KC', 'QC', 'QD', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KS', 'TC', 'JC', 'TH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'QS', 'QD', 'JD', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'AC', 'JH', 'KC', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AS', 'QC', 'JS', 'AD', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'QC', 'JH', 'KC', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AS', 'KS', 'AC', 'QH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TC', 'TH', 'AD', 'QD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TD', 'TS', 'KD', 'JS', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AS', 'JH', 'QH', 'QD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TD', 'KS', 'JS', 'TC', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'AD', 'QC', 'AC', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'QS', 'KC', 'KD', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JS', 'QS', 'AD', 'TS', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'JH', 'JD', 'KH', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JC', 'KD', 'KS', 'QD', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'AS', 'QH', 'TH', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TS', 'JH', 'JD', 'TC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AS', 'KD', 'TH', 'TD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'AD', 'JS', 'QS', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'KH', 'QD', 'KS', 'QH']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  10
# Player  0 Score  17
# Player  1 Score  9
# Player  2 Score  19
# Player  3 Score  5
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'QC', 'QH', 'TD', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JH', 'AC', 'JC', 'KD', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TC', 'AH', 'TS', 'AS', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'AD', 'KS', 'QS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'KS', 'AS', 'TH', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QS', 'QC', 'AC', 'JC', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JH', 'KH', 'TD', 'TC', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QD', 'KC', 'KD', 'AD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'QS', 'KC', 'TD', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'KH', 'QC', 'KS', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'KD', 'AH', 'TS', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'JC', 'AS', 'TC', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QD', 'KD', 'TD', 'JH', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AD', 'KH', 'QH', 'JC', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QC', 'JS', 'TC', 'QS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'TH', 'TS', 'AC', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'KC', 'TD', 'QD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'JS', 'TH', 'QH', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'JH', 'QC', 'KS', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AC', 'AH', 'KD', 'TC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AS', 'TD', 'QS', 'KD', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QD', 'TH', 'JC', 'TC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AC', 'AD', 'JD', 'KC', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KS', 'AH', 'KH', 'JH', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TC', 'AS', 'QH', 'TS', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AD', 'KD', 'JD', 'TD', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KS', 'KH', 'KC', 'QS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JS', 'QD', 'AC', 'JC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
# ...
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KS', 'KC', 'AS', 'QS', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TH', 'TS', 'KH', 'JH', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QC', 'TD', 'KD', 'QS', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JS', 'JD', 'QH', 'KS', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'AH', 'JC', 'KC', 'TC']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  10
# Player  0 Score  15
# Player  1 Score  14
# Player  2 Score  12
# Player  3 Score  9
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'TH', 'TD', 'QS', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'QC', 'KS', 'TC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JH', 'QH', 'TS', 'KH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AS', 'JS', 'JD', 'JC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TS', 'KD', 'KS', 'TC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'JH', 'AS', 'QS', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QC', 'AD', 'KH', 'TH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'JD', 'QH', 'AC', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JS', 'QC', 'AC', 'AH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'KS', 'JH', 'JC', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TH', 'QH', 'TS', 'KD', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TD', 'QD', 'KH', 'TC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KD', 'KS', 'AC', 'KC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AS', 'TC', 'JS', 'JH', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TS', 'TD', 'QS', 'TH', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JD', 'QH', 'KH', 'QD', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AD', 'QS', 'KD', 'KS', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'AS', 'JD', 'JC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QC', 'TD', 'TS', 'QH', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JS', 'AC', 'TH', 'JH', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QC', 'TD', 'KC', 'QH', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QS', 'KS', 'JH', 'KD', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AH', 'KH', 'AD', 'AC', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TS', 'AS', 'TC', 'TH', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JC', 'TD', 'AD', 'JH', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JD', 'KD', 'TS', 'AS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KH', 'AH', 'JS', 'TC', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'QS', 'QC', 'QH', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'TS', 'AC', 'AH', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JH', 'QS', 'QH', 'KD', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'TC', 'TH', 'AD', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JS', 'QD', 'KS', 'KH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QH', 'TH', 'QC', 'TS', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AD', 'TC', 'JC', 'QD', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TD', 'KH', 'QS', 'KS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JD', 'KC', 'JS', 'AS', 'AC']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  9
# Player  0 Score  15
# Player  1 Score  7
# Player  2 Score  10
# Player  3 Score  13
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'TD', 'KH', 'AH', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'TH', 'TS', 'KS', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AC', 'JD', 'QS', 'QD', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AD', 'KC', 'KD', 'TC', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TC', 'JD', 'AH', 'JS', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'KH', 'TH', 'AD', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AC', 'TD', 'AS', 'KS', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QC', 'TS', 'QH', 'QS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TS', 'QD', 'JH', 'QS', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'QC', 'JD', 'KH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JS', 'AD', 'AS', 'KD', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'KS', 'TC', 'TH', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JC', 'KS', 'AD', 'TS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AC', 'TH', 'QC', 'KH', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QD', 'QH', 'JS', 'JD', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KD', 'TC', 'AS', 'QS', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KH', 'JC', 'QH', 'JD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TC', 'JH', 'JS', 'TH', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['AD', 'KS', 'AH', 'AS', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QC', 'TD', 'AC', 'KC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'TS', 'QC', 'JC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JS', 'KS', 'AC', 'AD', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JD', 'AS', 'TH', 'KH', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QH', 'KD', 'AH', 'QD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'JC', 'TC', 'TH', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KC', 'KS', 'AS', 'AD', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JH', 'QD', 'JD', 'TD', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KD', 'QS', 'JS', 'AH', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TS', 'AD', 'AH', 'JD', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QC', 'KC', 'TH', 'QS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'KH', 'JC', 'TC', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AS', 'TD', 'AC', 'JS', 'QH']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  8
# Player  0 Score  16
# Player  1 Score  7
# Player  2 Score  8
# Player  3 Score  9
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KS', 'QD', 'AH', 'JC', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'JH', 'KC', 'AS', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'KH', 'JS', 'QS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QH', 'KD', 'TD', 'AC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TC', 'KH', 'TS', 'JH', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AS', 'QH', 'AC', 'AD', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QC', 'JS', 'TD', 'AH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QD', 'KC', 'JC', 'JD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JD', 'AC', 'TS', 'JH', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KS', 'AH', 'AS', 'QC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TH', 'KD', 'KH', 'JS', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JC', 'KC', 'QD', 'TD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JH', 'JS', 'QD', 'KC', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KH', 'TS', 'AS', 'QH', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KD', 'TC', 'QS', 'QC', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JD', 'TH', 'AH', 'JC', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KC', 'TH', 'JC', 'AD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TS', 'KS', 'KD', 'TD', 'AC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'QC', 'TC', 'JD', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JS', 'AH', 'QH', 'AS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JS', 'TH', 'KH', 'JD', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'AC', 'AD', 'KD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JC', 'AH', 'KS', 'JH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TC', 'QD', 'AS', 'KC', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TC', 'KS', 'JC', 'AH', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['JD', 'QC', 'AC', 'JS', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TD', 'KC', 'TS', 'KH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QH', 'AD', 'QD', 'TH', 'JH']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  7
# Player  0 Score  6
# Player  1 Score  16
# Player  2 Score  4
# Player  3 Score  9
#
# ===========================================
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'KS', 'TS', 'QH', 'JD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AH', 'AD', 'KD', 'TC', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['QS', 'KC', 'QD', 'TD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AC', 'KH', 'JS', 'AS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KD', 'KS', 'KC', 'AS', 'AH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TD', 'TS', 'QD', 'JH', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QC', 'JD', 'AC', 'AD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JC', 'KH', 'JS', 'QH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TD', 'AD', 'JH', 'JD', 'TC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KS', 'AS', 'KC', 'JC', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QD', 'AC', 'QS', 'KD', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QC', 'TS', 'KH', 'AH', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AC', 'TC', 'QC', 'JD', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AH', 'JH', 'TH', 'AS', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KC', 'KD', 'JS', 'TS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TD', 'QH', 'AD', 'JC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KS', 'AC', 'QC', 'QD', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AS', 'JD', 'AD', 'KH', 'QS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AH', 'TC', 'JS', 'QH', 'TS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TH', 'KC', 'JC', 'TD', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AD', 'QH', 'QC', 'JS', 'AS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KH', 'TC', 'AH', 'KD', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['JC', 'TH', 'JH', 'KC', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['QS', 'AC', 'TS', 'JD', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['TS', 'JS', 'KS', 'JD', 'KC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['QH', 'AD', 'QS', 'TC', 'JH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['AH', 'QD', 'AC', 'AS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    C
#   My Hand:  ['KH', 'KD', 'JC', 'TD', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['KC', 'AD', 'JD', 'QS', 'QD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['TC', 'QC', 'JC', 'AS', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['JS', 'TD', 'TS', 'JH', 'TH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    H
#   My Hand:  ['QH', 'AC', 'AH', 'KD', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AS', 'TH', 'TS', 'JH', 'KH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['KS', 'QD', 'QC', 'TD', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['TC', 'QH', 'KD', 'QS', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    S
#   My Hand:  ['AH', 'KC', 'JD', 'AC', 'JC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JH', 'JC', 'TC', 'AH', 'AD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KD', 'QS', 'TH', 'AC', 'QH']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['TS', 'TD', 'QD', 'KC', 'KS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KH', 'JS', 'JD', 'AS', 'QC']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['KS', 'QS', 'KH', 'AH', 'KD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JD', 'AD', 'QH', 'JH', 'JS']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['AS', 'QC', 'AC', 'TH', 'TD']
#   Played:
#   Order:
# CURRENT SITUATION:
#   Trump:    D
#   My Hand:  ['JC', 'KC', 'QD', 'TS', 'TC']
#   Played:
#   Order:
#
# ========= End of Tournament Score ========Games:  11
# Player  0 Score  14
# Player  1 Score  12
# Player  2 Score  14
# Player  3 Score  15
#
# ===========================================
#
# ========= OVERALL Tournament wins 1000/1000 ==========
# Player Wins   Win pct
#   1      245    0.24
#   2      270    0.27
#   3      249    0.25
#   4      236    0.24
#
# ========= OVERALL Tricks taken  out of 45875==========
# Player Hands  Win pct
#   1    11366    0.25
#   2    11508    0.25
#   3    11517    0.25
#   4    11484    0.25
#
# =========================================
#  Total tricks played:  45875
#  Total games played:  9175
#  Total tournaments played:  1000
#  Average tricks per Tournament:  45.875
#  Average games per Tournament:  9.175
#  Average tricks per game:  5.0
